# %% [markdown]
# # Show the dataframe shape.

# %%
import pandas as pd
import numpy as np
marketing_data = pd.read_csv('/Users/joluhergo/Desktop/Ironhack/labs/lab-customer-analysis-r2/marketing_customer_analysis.csv')

# %%
marketing_data.shape
# Out:
# (10910, 26)

# %% [markdown]
# # Standardize header names.

# %%
marketing_data.columns
# Out:
# Index(['Unnamed: 0', 'Customer', 'State', 'Customer Lifetime Value',
#        'Response', 'Coverage', 'Education', 'Effective To Date',
#        'EmploymentStatus', 'Gender', 'Income', 'Location Code',
#        'Marital Status', 'Monthly Premium Auto', 'Months Since Last Claim',
#        'Months Since Policy Inception', 'Number of Open Complaints',
#        'Number of Policies', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Total Claim Amount', 'Vehicle Class', 'Vehicle Size',
#        'Vehicle Type'],
#       dtype='object')

# %%
marketing_data.columns = list(map(lambda x: x.upper(), marketing_data.columns))

# %%
marketing_data.columns
# Out:
# Index(['UNNAMED: 0', 'CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE',
#        'RESPONSE', 'COVERAGE', 'EDUCATION', 'EFFECTIVE TO DATE',
#        'EMPLOYMENTSTATUS', 'GENDER', 'INCOME', 'LOCATION CODE',
#        'MARITAL STATUS', 'MONTHLY PREMIUM AUTO', 'MONTHS SINCE LAST CLAIM',
#        'MONTHS SINCE POLICY INCEPTION', 'NUMBER OF OPEN COMPLAINTS',
#        'NUMBER OF POLICIES', 'POLICY TYPE', 'POLICY', 'RENEW OFFER TYPE',
#        'SALES CHANNEL', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS', 'VEHICLE SIZE',
#        'VEHICLE TYPE'],
#       dtype='object')

# %% [markdown]
# # Which columns are numerical?

# %%
marketing_data.head(2)
# Out:
#    UNNAMED: 0 CUSTOMER       STATE  CUSTOMER LIFETIME VALUE RESPONSE COVERAGE  \
# 0           0  DK49336     Arizona              4809.216960       No    Basic
# 1           1  KX64629  California              2228.525238       No    Basic
#
#   EDUCATION EFFECTIVE TO DATE EMPLOYMENTSTATUS GENDER  ...  \
# 0   College           2/18/11         Employed      M  ...
# 1   College           1/18/11       Unemployed      F  ...
#
#    NUMBER OF OPEN COMPLAINTS NUMBER OF POLICIES     POLICY TYPE        POLICY  \
# 0                        0.0                  9  Corporate Auto  Corporate L3
# 1                        0.0                  1   Personal Auto   Personal L3
#
#    RENEW OFFER TYPE  SALES CHANNEL  TOTAL CLAIM AMOUNT  VEHICLE CLASS  \
# 0            Offer3          Agent          292.800000  Four-Door Car
# 1            Offer4    Call Center          744.924331  Four-Door Car
#
#   VEHICLE SIZE VEHICLE TYPE
# 0      Medsize          NaN
# 1      Medsize          NaN
#
# ...

# %%
marketing_data.dtypes
# Out:
# UNNAMED: 0                         int64
# CUSTOMER                          object
# STATE                             object
# CUSTOMER LIFETIME VALUE          float64
# RESPONSE                          object
# COVERAGE                          object
# EDUCATION                         object
# EFFECTIVE TO DATE                 object
# EMPLOYMENTSTATUS                  object
# GENDER                            object
# INCOME                             int64
# LOCATION CODE                     object
# MARITAL STATUS                    object
# MONTHLY PREMIUM AUTO               int64
# MONTHS SINCE LAST CLAIM          float64
# MONTHS SINCE POLICY INCEPTION      int64
# NUMBER OF OPEN COMPLAINTS        float64
# NUMBER OF POLICIES                 int64
# POLICY TYPE                       object
# POLICY                            object
# RENEW OFFER TYPE                  object
# SALES CHANNEL                     object
# TOTAL CLAIM AMOUNT               float64
# ...

# %%
n = ['int64','float64']
marketing_data.select_dtypes(include=n)
# Out:
#        UNNAMED: 0  CUSTOMER LIFETIME VALUE  INCOME  MONTHLY PREMIUM AUTO  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        MONTHS SINCE LAST CLAIM  MONTHS SINCE POLICY INCEPTION  \
# ...

# %% [markdown]
# # Which columns are categorical?

# %%
marketing_data.select_dtypes(include='object')
# Out:
#       CUSTOMER       STATE RESPONSE  COVERAGE EDUCATION EFFECTIVE TO DATE  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EMPLOYMENTSTATUS GENDER LOCATION CODE MARITAL STATUS     POLICY TYPE  \
# ...

# %% [markdown]
# # Check and deal with NaN values.

# %% [markdown]
# marketing_data.isna()

# %%
marketing_data.isna().sum()
# Out:
# UNNAMED: 0                          0
# CUSTOMER                            0
# STATE                             631
# CUSTOMER LIFETIME VALUE             0
# RESPONSE                          631
# COVERAGE                            0
# EDUCATION                           0
# EFFECTIVE TO DATE                   0
# EMPLOYMENTSTATUS                    0
# GENDER                              0
# INCOME                              0
# LOCATION CODE                       0
# MARITAL STATUS                      0
# MONTHLY PREMIUM AUTO                0
# MONTHS SINCE LAST CLAIM           633
# MONTHS SINCE POLICY INCEPTION       0
# NUMBER OF OPEN COMPLAINTS         633
# NUMBER OF POLICIES                  0
# POLICY TYPE                         0
# POLICY                              0
# RENEW OFFER TYPE                    0
# SALES CHANNEL                       0
# TOTAL CLAIM AMOUNT                  0
# VEHICLE CLASS                     622
# VEHICLE SIZE                      622
# ...

# %%
marketing_data[marketing_data['STATE'].isna()==True].head(60)
#checking how NaN values seem to be distributed
# Out:
#      UNNAMED: 0 CUSTOMER STATE  CUSTOMER LIFETIME VALUE RESPONSE  COVERAGE  \
# 5             5  HO81102   NaN              4745.181764      NaN     Basic
# 11           11  GE63585   NaN              2420.711888      NaN     Basic
# 58           58  BR69566   NaN             14019.833140      NaN     Basic
# 62           62  UF44021   NaN              2108.493744      NaN     Basic
# 126         126  TE60343   NaN              4716.264294      NaN     Basic
# 131         131  QK24293   NaN              6265.343299      NaN  Extended
# 155         155  JG35886   NaN              4111.888285      NaN   Premium
# 168         168  FV22585   NaN              6960.920371      NaN  Extended
# 169         169  AU23837   NaN              5010.379310      NaN     Basic
# 190         190  VZ18907   NaN             21991.615980      NaN     Basic
# 226         226  VK57280   NaN              4727.354548      NaN     Basic
# ...

# %% [markdown]
# We cant drop the rows with NaN values because they also have importante information.
# They are not a lot of NaN values, so we can check if we can fill some of them

# %%
marketing_data['STATE'].value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: STATE, dtype: int64

# %%
marketing_data['RESPONSE'].value_counts()
# Out:
# No     8813
# Yes    1466
# Name: RESPONSE, dtype: int64

# %%
marketing_data['NUMBER OF OPEN COMPLAINTS'].value_counts()
# Out:
# 0.0    8160
# 1.0    1145
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: NUMBER OF OPEN COMPLAINTS, dtype: int64

# %%
marketing_data['VEHICLE CLASS'].value_counts()
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: VEHICLE CLASS, dtype: int64

# %%
marketing_data['VEHICLE SIZE'].value_counts()
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# Name: VEHICLE SIZE, dtype: int64

# %%
marketing_data['VEHICLE TYPE'].value_counts()
# Out:
# A    5428
# Name: VEHICLE TYPE, dtype: int64

# %% [markdown]
# Wewe could fill some of the NaN values with the average or the most frequent element of a column, but I think it is a better option to fill it more randomly using the data from the previous row, as otherwise it would increase too much some of the values

# %%
marketing_data_filled = marketing_data.fillna(method='backfill')

# %%
marketing_data_filled.isna().sum()
# Out:
# UNNAMED: 0                       0
# CUSTOMER                         0
# STATE                            1
# CUSTOMER LIFETIME VALUE          0
# RESPONSE                         1
# COVERAGE                         0
# EDUCATION                        0
# EFFECTIVE TO DATE                0
# EMPLOYMENTSTATUS                 0
# GENDER                           0
# INCOME                           0
# LOCATION CODE                    0
# MARITAL STATUS                   0
# MONTHLY PREMIUM AUTO             0
# MONTHS SINCE LAST CLAIM          0
# MONTHS SINCE POLICY INCEPTION    0
# NUMBER OF OPEN COMPLAINTS        0
# NUMBER OF POLICIES               0
# POLICY TYPE                      0
# POLICY                           0
# RENEW OFFER TYPE                 0
# SALES CHANNEL                    0
# TOTAL CLAIM AMOUNT               0
# VEHICLE CLASS                    0
# VEHICLE SIZE                     0
# VEHICLE TYPE                     1
# dtype: int64

# %% [markdown]
# We can check, taking 'STATE' as example, that this method doesnt change our values as mach as filling the most frequent (California would have increased in 631, wich is an increase of 17,7%)

# %%
marketing_data['STATE'].value_counts()
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: STATE, dtype: int64

# %%
marketing_data_filled['STATE'].value_counts()
# Out:
# California    3765
# Oregon        3085
# Arizona       2067
# Nevada        1051
# Washington     941
# Name: STATE, dtype: int64
