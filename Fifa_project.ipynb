# %%
import pandas as pd
import numpy as np
fifa_data = pd.read_csv('/Users/joluhergo/Desktop/Ironhack/Fifa_project/fifa21_train.csv')

# %%
print(fifa_data.shape)
fifa_data.head(3)
# Out:
# (11701, 101)
#        ID           Name  Age  Nationality                     Club   BP  \
# 0  184383      A. Pasche   26  Switzerland        FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR  Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                 Al Hilal  CAM
#
#    Position                               Team & Contract Height  Weight  ...  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  ...
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  ...
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs  ...
#
#     CDM   RDM   RWB    LB   LCB    CB   RCB    RB    GK  OVA
# 0  59+1  59+1  59+1  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1  53+2  53+2  57+2  53+2  48+2  48+2  48+2  53+2  18+2   77
# 2  56+2  56+2  59+2  53+2  41+2  41+2  41+2  53+2  12+2   80
#
# [3 rows x 101 columns]

# %%
fifa_data.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Nationality', 'Club', 'BP', 'Position',
#        'Team & Contract', 'Height', 'Weight',
#        ...
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK', 'OVA'],
#       dtype='object', length=101)

# %%
fifa_data.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11701 entries, 0 to 11700
# Columns: 101 entries, ID to OVA
# dtypes: float64(10), int64(43), object(48)
# memory usage: 39.7 MB

# %%
fifa_data._get_numeric_data().columns
# Out:
# Index(['ID', 'Age', 'Growth', 'Attacking', 'Crossing', 'Finishing',
#        'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling',
#        'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'OVA'],
#       dtype='object')

# %%
categorical =fifa_data.select_dtypes('object')
numerical = fifa_data.select_dtypes('number')

# %%
categorical.isna().sum()
# Out:
# Name                   0
# Nationality            0
# Club                  18
# BP                     0
# Position             288
# Team & Contract        0
# Height                 0
# Weight                 0
# foot                   0
# Joined                41
# Loan Date End      11072
# Value                  0
# Wage                   0
# Release Clause         0
# Contract               0
# W/F                    0
# SM                     0
# A/W                   59
# D/W                   59
# IR                     0
# Hits                   0
# LS                     0
# ST                     0
# RS                     0
# LW                     0
# LF                     0
# CF                     0
# RF                     0
# RW                     0
# LAM                    0
# CAM                    0
# RAM                    0
# LM                     0
# LCM                    0
# CM                     0
# RCM                    0
# RM                     0
# ...

# %%
fifa_data.isna().sum()
# Out:
# ID              0
# Name            0
# Age             0
# Nationality     0
# Club           18
#                ..
# CB              0
# RCB             0
# RB              0
# GK              0
# OVA             0
# Length: 101, dtype: int64

# %%
fifa_data.isna()
# Out:
#           ID   Name    Age  Nationality   Club     BP  Position  \
# 0      False  False  False        False  False  False     False
# 1      False  False  False        False  False  False     False
# 2      False  False  False        False  False  False     False
# 3      False  False  False        False  False  False     False
# 4      False  False  False        False  False  False     False
# ...      ...    ...    ...          ...    ...    ...       ...
# 11696  False  False  False        False  False  False     False
# 11697  False  False  False        False  False  False     False
# 11698  False  False  False        False  False  False     False
# 11699  False  False  False        False  False  False      True
# 11700  False  False  False        False  False  False     False
#
#        Team & Contract  Height  Weight  ...    CDM    RDM    RWB     LB  \
# 0                False   False   False  ...  False  False  False  False
# ...

# %% [markdown]
# fifa_data_filled = fifa_data.fillna(method='backfill')

# %%
def clean_club(columns):
    columns.fillna("Free agent")
    return

# %%
#categorical["Club"] = categorical["Club"].apply(clean_club)
#categorical['Club'].isna().sum()

# %%
categorical["Club"] = categorical["Club"].fillna("Free Agent")
# Out:
# <ipython-input-13-1b24aa6d8bd2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical["Club"] = categorical["Club"].fillna("Free Agent")

# %%
#categorical["Club"] = categorical["Club"].apply(clean_club)

# %%
categorical["Position"].unique
# Out:
# <bound method Series.unique of 0           CM CDM
# 1         ST LW LM
# 2           CAM CF
# 3           CDM CM
# 4           CDM CM
#            ...
# 11696           LB
# 11697           GK
# 11698    LM CAM RM
# 11699          NaN
# 11700    ST CAM LM
# Name: Position, Length: 11701, dtype: object>

# %%
categorical.isna().sum()
# Out:
# Name                   0
# Nationality            0
# Club                   0
# BP                     0
# Position             288
# Team & Contract        0
# Height                 0
# Weight                 0
# foot                   0
# Joined                41
# Loan Date End      11072
# Value                  0
# Wage                   0
# Release Clause         0
# Contract               0
# W/F                    0
# SM                     0
# A/W                   59
# D/W                   59
# IR                     0
# Hits                   0
# LS                     0
# ST                     0
# RS                     0
# LW                     0
# LF                     0
# CF                     0
# RF                     0
# RW                     0
# LAM                    0
# CAM                    0
# RAM                    0
# LM                     0
# LCM                    0
# CM                     0
# RCM                    0
# RM                     0
# ...

# %%
categorical.isna().sum()
# Out:
# Name                   0
# Nationality            0
# Club                   0
# BP                     0
# Position             288
# Team & Contract        0
# Height                 0
# Weight                 0
# foot                   0
# Joined                41
# Loan Date End      11072
# Value                  0
# Wage                   0
# Release Clause         0
# Contract               0
# W/F                    0
# SM                     0
# A/W                   59
# D/W                   59
# IR                     0
# Hits                   0
# LS                     0
# ST                     0
# RS                     0
# LW                     0
# LF                     0
# CF                     0
# RF                     0
# RW                     0
# LAM                    0
# CAM                    0
# RAM                    0
# LM                     0
# LCM                    0
# CM                     0
# RCM                    0
# RM                     0
# ...

# %%
categorical["Joined"]
# Out:
# 0         Jul 1, 2015
# 1        Jan 16, 2015
# 2        Jan 31, 2019
# 3         Jul 1, 2016
# 4         Jul 1, 2018
#              ...
# 11696     Feb 8, 2018
# 11697     Jul 1, 2019
# 11698    Jan 23, 2019
# 11699             NaN
# 11700    Jul 22, 2019
# Name: Joined, Length: 11701, dtype: object

# %%
import datetime
first_day = datetime.date(2020, 9, 1)
first_day.strftime('%b %d, %Y')
# Out:
# 'Sep 01, 2020'

# %%
categorical["Joined"] =categorical["Joined"].fillna(first_day.strftime('%b %d, %Y'))
# Out:
# <ipython-input-20-9883d063ccf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical["Joined"] =categorical["Joined"].fillna(first_day.strftime('%b %d, %Y'))

# %%
categorical["Joined"].isna().sum()
# Out:
# 0

# %% [markdown]
# Replacing the NaN in the Loan Date End with the last day of June next year
# Loans for players expire at  the end of the season. Soccer seasons usually end by June

# %%
categorical["Loan Date End"]
# Out:
# 0                 NaN
# 1        Dec 31, 2020
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 11696             NaN
# 11697             NaN
# 11698             NaN
# 11699             NaN
# 11700             NaN
# Name: Loan Date End, Length: 11701, dtype: object

# %% [markdown]
# loan_date_end = datetime.date(2021, 6, 1)
# first_day.strftime('%b %d, %Y')
# res = calendar.monthrange(test_date.year,test_date.month)[1]

# %%
loan_date_end = datetime.date(2021, 6, 1)
loan_date_end.strftime('%b %d, %Y')
# Out:
# 'Jun 01, 2021'

# %%
categorical["Joined"] =categorical["Joined"].fillna(first_day.strftime('%b %d, %Y'))
# Out:
# <ipython-input-24-9883d063ccf3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   categorical["Joined"] =categorical["Joined"].fillna(first_day.strftime('%b %d, %Y'))

# %%
print(categorical.columns)
# Out:
# Index(['Name', 'Nationality', 'Club', 'BP', 'Position', 'Team & Contract',
#        'Height', 'Weight', 'foot', 'Joined', 'Loan Date End', 'Value', 'Wage',
#        'Release Clause', 'Contract', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'GK'],
#       dtype='object')

# %%
categorical = categorical.drop(["Loan Date End"], axis=1)

# %%
categorical["LS"]
# Out:
# 0        58+1
# 1        77+0
# 2        73+2
# 3        50+2
# 4        56+2
#          ...
# 11696    48+2
# 11697    28+2
# 11698    62+2
# 11699    68+0
# 11700    64+2
# Name: LS, Length: 11701, dtype: object

# %% [markdown]
# https://www.pythonforbeginners.com/exceptions/valueerror-invalid-literal-for-int-with-base-10

# %%
def x(string):
    a = int(string.split("+")[0])
    b = int(string.split("+")[1])
    return a + b

# %%
cat = categorical[["LS",'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM','RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB','RCB', 'RB', 'GK']]
for column in cat:
    cat[column] = cat[column].apply(x)
display(cat)
# Out:
# <ipython-input-29-7bec21ec193a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cat[column] = cat[column].apply(x)
#        LS  ST  RS  LW  LF  CF  RF  RW  LAM  CAM  ...  LDM  CDM  RDM  RWB  LB  \
# 0      59  59  59  61  62  62  62  61   64   64  ...   60   60   60   60  59
# 1      77  77  77  77  77  77  77  77   77   77  ...   55   55   55   59  55
# 2      75  75  75  80  79  79  79  80   80   80  ...   58   58   58   61  55
# 3      52  52  52  51  51  51  51  51   55   55  ...   60   60   60   58  59
# 4      58  58  58  59  59  59  59  59   63   63  ...   66   66   66   66  65
# ...    ..  ..  ..  ..  ..  ..  ..  ..  ...  ...  ...  ...  ...  ...  ...  ..
# ...

# %%
# categorical["LS"] = categorical["LS"].apply(x)

# %% [markdown]
# for column in cat:
#     cat[column] = cat[column].apply(x)
# display(cat)

# %%
categorical[categorical["Position"].isna()]
# Out:
#                  Name          Nationality             Club  BP Position  \
# 17          M. Oddo B                Italy            Lecce  CM      NaN
# 59          P. Netzer              Austria       SCR Altach  CB      NaN
# 132       A. Jaakkola              Finland   Bristol Rovers  GK      NaN
# 157         B. Clarke  Republic of Ireland    Bradford City  ST      NaN
# 214              Mora                Spain        Getafe CF  CM      NaN
# ...               ...                  ...              ...  ..      ...
# 11350     F. Eastwood                Wales  Southend United  ST      NaN
# 11580            Nenê               Brazil  West Ham United  LW      NaN
# 11650       J. Koller       Czech Republic       Free Agent  ST      NaN
# 11670        T. Berni                Italy            Inter  GK      NaN
# 11699  Anderson Silva               Brazil         Barnsley  CM      NaN
#
#                    Team & Contract Height  Weight   foot        Joined  ...  \
# ...

# %%
cat.max(axis=1)
# Out:
# 0        64
# 1        77
# 2        80
# 3        60
# 4        66
#          ..
# 11696    65
# 11697    71
# 11698    68
# 11699    72
# 11700    67
# Length: 11701, dtype: int64

# %%
list_cat_max = cat.max(axis=1)

# %%
index_na_positions =list(categorical[categorical["Position"].isna()].index.values)

# %%
#for i in range(len(categorical)):
    #if categorical.iloc[i]["Position"].isna() == True:
        #cat["Position"][i] = cat.max(axis=1)[i]

# %%
categorical["Position"].dropna(axis=0)
# Out:
# 0           CM CDM
# 1         ST LW LM
# 2           CAM CF
# 3           CDM CM
# 4           CDM CM
#            ...
# 11695           ST
# 11696           LB
# 11697           GK
# 11698    LM CAM RM
# 11700    ST CAM LM
# Name: Position, Length: 11413, dtype: object

# %%
numerical = fifa_data.select_dtypes('number')

# %%
numerical.shape
# Out:
# (11701, 53)

# %%
numerical.isna().sum()
# Out:
# ID                    0
# Age                   0
# Growth                0
# Attacking             0
# Crossing              0
# Finishing             0
# Heading Accuracy      0
# Short Passing         0
# Volleys              41
# Skill                 0
# Dribbling             0
# Curve                41
# FK Accuracy           0
# Long Passing          0
# Ball Control          0
# Movement              0
# Acceleration          0
# Sprint Speed          0
# Agility              41
# Reactions             0
# Balance              41
# Power                 0
# Shot Power            0
# Jumping              41
# Stamina               0
# Strength              0
# Long Shots            0
# Mentality             0
# Aggression            0
# Interceptions         7
# Positioning           7
# Vision               41
# Penalties             0
# Composure           279
# Defending             0
# Marking               0
# Standing Tackle       0
# Sliding Tackle       41
# ...

# %%
volleys = numerical[numerical["Volleys"].isna()==True]

# %%
numerical[numerical["Volleys"].isna()==True]
numerical = numerical[numerical["Volleys"].isna()==False]

# %%
mean_volleys = numerical['Volleys'].mean()
numerical['Volleys'] = numerical['Volleys'].fillna(mean_volleys)
numerical['Volleys']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3ceb170d9380> in <module>
# ----> 1 mean_volleys = numerical['Volleys'].mean()
#       2 numerical['Volleys'] = numerical['Volleys'].fillna(mean_volleys)
#       3 numerical['Volleys']
#
# NameError: name 'numerical' is not defined

# %%
mean_composure = fifa_num['composure'].mean()
fifa_num['composure'] = fifa_num['composure'].fillna(mean_composure)
fifa_num['composure']
